# %%
#import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
#Connect to Website
url = 'https://www.amazon.com/Data-Science-Analytics-Scientists-T-Shirt/dp/B09RBGMLVB/ref=sr_1_1?crid=2HZ5KA32R3DEA&dib=eyJ2IjoiMSJ9._nYL2SX89DVv-xBgJwjLb6NUtWvyDPanOZF1Na1IjnxsagVKeF-89g1J6R2YPHF9AzXncX2PYfUKz_lGkh9O8kioOy_gJWDz1ZnXk9A4ELRB64Tsnru7Er6uevPAYRCck0o7P2FTU1X1senEtzsxGuekeaZtSDh9aoFMrHcUyYjLeB5Id9ueFeR2Ntv-fPloWxTZJxgdB3jOXwwlGLvzEmG2xNlTqOYF3kbudB5YRBaQQrZZBjYRl5KDpfC90g-JdM5jWmg7iY9oZAGgdgze1JEPPfe3AYjjL2jbMgcmgjM.ubbZQq7SV0HKtvKJ_G6pD5jo8Rb_xYp-lTkukNR3Qxg&dib_tag=se&keywords=data%2Banalyst%2Bshirt&qid=1776351533&sprefix=data%2Banalyst%2Caps%2C470&sr=8-1&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'

headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept-Language": "en-US,en;q=0.9"
}

page = requests.get(url, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title_tag = soup2.find(id='productTitle')

if title_tag:
    title = title_tag.get_text().strip()
else:
    print("Title not found")
    title = "N/A"   # FIX HERE


price_symbol_tag = soup2.find(class_='a-price-symbol')
price_whole_tag = soup2.find(class_='a-price-whole')
price_fraction_tag = soup2.find(class_='a-price-fraction')

if price_symbol_tag and price_whole_tag and price_fraction_tag:
    price_symbol = price_symbol_tag.get_text(strip=True)
    price_whole = price_whole_tag.get_text(strip=True)
    price_fraction = price_fraction_tag.get_text(strip=True)

    price = f'{price_symbol}{price_whole}.{price_fraction}'
else:
    price = "Price not found"


print(title)
print(price)
# Out:
# Data Science. Big Data Analytics. for Data Scientists T-Shirt
# PHP1,199..00

# %%
import datetime

today = datetime.date.today()

print(today)
# Out:
# 2026-04-17

# %%
import csv 

header = ['Title', 'Price', 'Date']
data = [title, price, today]


with open('AmazonWebScraperDatasetProject.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\heide\AmazonWebScraperDatasetProject.csv')

print(df)
# Out:
#                                                Title         Price        Date
# 0  Data Science. Big Data Analytics. for Data Sci...  PHP1,199..00  2026-04-17

# %%
# Appending data to the csv
with open('AmazonWebScraperDatasetProject.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one function


def check_price():
    URL = 'https://www.amazon.com/Data-Science-Analytics-Scientists-T-Shirt/dp/B09RBGMLVB/ref=sr_1_1?crid=2HZ5KA32R3DEA&dib=eyJ2IjoiMSJ9._nYL2SX89DVv-xBgJwjLb6NUtWvyDPanOZF1Na1IjnxsagVKeF-89g1J6R2YPHF9AzXncX2PYfUKz_lGkh9O8kioOy_gJWDz1ZnXk9A4ELRB64Tsnru7Er6uevPAYRCck0o7P2FTU1X1senEtzsxGuekeaZtSDh9aoFMrHcUyYjLeB5Id9ueFeR2Ntv-fPloWxTZJxgdB3jOXwwlGLvzEmG2xNlTqOYF3kbudB5YRBaQQrZZBjYRl5KDpfC90g-JdM5jWmg7iY9oZAGgdgze1JEPPfe3AYjjL2jbMgcmgjM.ubbZQq7SV0HKtvKJ_G6pD5jo8Rb_xYp-lTkukNR3Qxg&dib_tag=se&keywords=data%2Banalyst%2Bshirt&qid=1776351533&sprefix=data%2Banalyst%2Caps%2C470&sr=8-1&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1'

    headers = { "User-Agent": "Mozilla/5.0",
    "Accept-Language": "en-US,en;q=0.9"}

    page = requests.get(url, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")
    
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    
    title_tag = soup2.find(id='productTitle')
    
    if title_tag:
        title = title_tag.get_text().strip()
    else:
        print("Title not found")
        title = "N/A"   # FIX HERE
    
    
    price_symbol_tag = soup2.find(class_='a-price-symbol')
    price_whole_tag = soup2.find(class_='a-price-whole')
    price_fraction_tag = soup2.find(class_='a-price-fraction')
    
    if price_symbol_tag and price_whole_tag and price_fraction_tag:
        price_symbol = price_symbol_tag.get_text(strip=True)
        price_whole = price_whole_tag.get_text(strip=True)
        price_fraction = price_fraction_tag.get_text(strip=True)
    
        price = f'{price_symbol}{price_whole}.{price_fraction}'
    else:
        price = "Price not found"

    import datetime

    today = datetime.date.today()
    
    import csv 

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\heide\AmazonWebScraperDatasetProject.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('bagorioburj@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below 1300 pesos! Now is your chance to buy!"
    body = "Alex, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Data-Science-Analytics-Scientists-T-Shirt/dp/B09RBGMLVB/ref=sr_1_1?crid=2HZ5KA32R3DEA&dib=eyJ2IjoiMSJ9._nYL2SX89DVv-xBgJwjLb6NUtWvyDPanOZF1Na1IjnxsagVKeF-89g1J6R2YPHF9AzXncX2PYfUKz_lGkh9O8kioOy_gJWDz1ZnXk9A4ELRB64Tsnru7Er6uevPAYRCck0o7P2FTU1X1senEtzsxGuekeaZtSDh9aoFMrHcUyYjLeB5Id9ueFeR2Ntv-fPloWxTZJxgdB3jOXwwlGLvzEmG2xNlTqOYF3kbudB5YRBaQQrZZBjYRl5KDpfC90g-JdM5jWmg7iY9oZAGgdgze1JEPPfe3AYjjL2jbMgcmgjM.ubbZQq7SV0HKtvKJ_G6pD5jo8Rb_xYp-lTkukNR3Qxg&dib_tag=se&keywords=data%2Banalyst%2Bshirt&qid=1776351533&sprefix=data%2Banalyst%2Caps%2C470&sr=8-1&customId=B0752XJYNL&customizationToken=MC_Assembly_1%23B0752XJYNL&th=1&psc=1"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'bagorioburj@gmail.com',
        msg
     
    )
